# %%
#%matplotlib nbagg
#%matplotlib inline
# %matplotlib notebook
#to show matplotlib in jupyter notebook

from ipynb.fs.full.piwebapi import getData

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
from itertools import count
import datetime

# %%
plt.style.use('fivethirtyeight')

x_vals = []
y_vals = []

index = count()

def animate(i):
    a,b = getData()
    x_vals.append(b)
    y_vals.append(a)
    
    plt.cla()
    #togetridofscientific notation
    #plt.ticklabel_format(axis = 'y' , useOffset=False, style='plain')
    plt.plot(x_vals, y_vals, 'ro', ms=1)
    plt.ylim(100, 800)
    plt.xlim(50,200)
    plt.xlabel('MS Press L in BAR')
    plt.ylabel('GEN MW')
    plt.title('MS PRESS and MW Relation')
    plt.tight_layout()


  

ani = FuncAnimation(plt.gcf(), animate, interval = 1000)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
