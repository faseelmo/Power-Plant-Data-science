# %%
#%matplotlib nbagg
#%matplotlib inline
# %matplotlib notebook
#to show matplotlib in jupyter notebook

from ipynb.fs.full.piwebapi import getData

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
from itertools import count
import datetime

# %%
plt.style.use('fivethirtyeight')


index = count()

def animate(i):
    data = pd.read_csv('u20data.csv')
    mw = data['gen_mw']
    ms_temp = data['ms_temp']
    ms_press = data['ms_pressure']
    
    print(mw, ms_temp,ms_press)
    plt.cla()
  
    plt.plot(ms_press, mw, 'ro', ms=1, label='Pressure in Bar')
    plt.plot(ms_temp, mw, 'bo', ms=1, label='Temp in °C')
    
    plt.ylim(100, 800)
    plt.xlim(50,600)
    
    plt.legend(loc='upper left')
    
    plt.ylabel('GEN MW')
    plt.title('MS Press & Temp and MW Relation')
    
    plt.tight_layout()

ani = FuncAnimation(plt.gcf(), animate, interval = 5000)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
animate(1)
# Out:
# 0    300.585938
# 1    300.585938
# 2    300.585938
# 3    300.585938
# 4    300.585938
# 5    300.585938
# 6    300.585938
# 7    300.585938
# 8    300.585938
# 9    300.585938
# Name: gen_mw, dtype: float64 0    479.7914
# 1    479.7914
# 2    479.7914
# 3    479.7914
# 4    479.7914
# 5    479.7914
# 6    479.7914
# 7    479.7914
# 8    479.7914
# 9    479.7914
# Name: ms_temp, dtype: float64 0    100.173828
# 1    100.173828
# 2    100.173828
# 3    100.173828
# 4    100.173828
# 5    100.173828
# 6    100.173828
# 7    100.173828
# 8    100.173828
# 9    100.173828
# Name: ms_pressure, dtype: float64
