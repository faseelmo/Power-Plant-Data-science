# %%
#%matplotlib nbagg
#%matplotlib inline
# %matplotlib notebook
#to show matplotlib in jupyter notebook

from ipynb.fs.full.piwebapi import getData

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
from itertools import count
import datetime
# Out:
# (306.9375, 89.40039, {'Name': 'Out of Serv', 'Value': 312, 'IsSystem': True}, 478.647278, datetime.datetime(2021, 6, 17, 12, 27, 15, 41612))

# %%
plt.style.use('fivethirtyeight')


index = count()

def animate(i):
    data = pd.read_csv('u20data.csv')
    mw = data['gen_mw']
    ms_temp = data['ms_temp']
    ms_press = data['ms_pressure']
    
    plt.cla()
  
    plt.plot(ms_press, mw, 'ro', ms=1, label='Pressure in Bar')
    plt.plot(ms_temp, mw, 'bo', ms=1, label='Temp in °C')
    
    plt.ylim(100, 800)
    plt.xlim(50,600)
    
    plt.legend(loc='upper left')
    
    plt.ylabel('GEN MW')
    plt.title('MS Press & Temp and MW Relation')
    
    plt.tight_layout()

ani = FuncAnimation(plt.gcf(), animate, interval = 5000)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
