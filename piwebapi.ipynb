# %%
#THIS FILE WILL NOT BE FURTHER UPDATED. IT EXIST ON THIS REPO ONLY TO DEMONSTRATE WEB API.

# %%
import requests, json

def getData():
    mw_endpoint = ''
    mw = requests.get(mw_endpoint, auth = ('USER NAME', 'PASS'))
    
    press_endpoint = ''
    ms_press = requests.get(press_endpoint, auth = ('USER NAME', 'PASS'))
    
    return mw.json()["Value"], ms_press.json()["Value"]

# %%
a,b = getData()
print("MW is",a, "and Left MS Press is", b)
# Out:
# MW is 492.1875 and Left MS Press is 145.038086
