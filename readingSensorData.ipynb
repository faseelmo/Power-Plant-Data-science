# %%
import csv 
import random 
import time 
from ipynb.fs.full.piwebapi import getData

fieldnames = ["time", "gen_mw", "ms_temp", "ms_pressure"]

with open('u20data.csv', 'w') as csv_file:
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()
    
while True:
    print(getData())
    
    with open('u20data.csv', 'a') as csv_file:
        csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        info = {
            "time": e,
            "gen_mw": a,
            "ms_temp": d,
            "ms_pressure": b
        }
        
        csv_writer.writerow(info)
        
        
    time.sleep(5)
